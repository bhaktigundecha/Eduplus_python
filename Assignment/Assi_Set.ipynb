# %%
country = {"India","America","Nepal","pakistan","Bangladesh"} #1
print("The country set is :", country)
# Out:
# The country set is : {'America', 'pakistan', 'Nepal', 'Bangladesh', 'India'}

# %%
num_set = {12,54,12,76,23,8,12} #2
print("Set with duplicates:", num_set)
# Out:
# Set with duplicates: {54, 23, 8, 12, 76}

# %%
fruits = ["apple", "banana","cherry"] #3
fruit_set = set(fruits)
print("Set from list of fruits: ", fruit_set)
# Out:
# Set from list of fruits:  {'cherry', 'apple', 'banana'}

# %%
fruit_set.add("mango") #4
print("Set after add():", fruit_set)
# Out:
# Set after add(): {'cherry', 'apple', 'mango', 'banana'}

# %%
fruit_set.update(["pineapple","chikoo"]) #5
print("Set after update():", fruit_set)
# Out:
# Set after update(): {'apple', 'mango', 'chikoo', 'cherry', 'pineapple', 'banana'}

# %%
fruit_set.add("mango") #6
print(fruit_set)
# Out:
# {'apple', 'mango', 'chikoo', 'cherry', 'pineapple', 'banana'}

# %%
fruit_set.remove("chikoo") #7
print("Set after remove():", fruit_set)
# Out:
# Set after remove(): {'apple', 'mango', 'cherry', 'pineapple', 'banana'}

# %%
fruit_set.discard(34) #8
print("Set after discard():",fruit_set)
# Out:
# Set after discard(): {'apple', 'mango', 'cherry', 'pineapple', 'banana'}

# %%
removed_ele = fruit_set.pop() #9
print("Removed element is:", removed_ele)
print("Set after pop():", fruit_set)
# Out:
# Removed element is: apple
# Set after pop(): {'mango', 'cherry', 'pineapple', 'banana'}

# %%
fruit_set.clear() #10
print("Set after clear():", fruit_set)
# Out:
# Set after clear(): set()

# %%
A = {1,4,2,7,8,6} #11
B = {3,9,6,2,1,4}
print("Set A is :", A)
print("Set B is :", B)
print("Union of set A and B is(A|B):", A|B)
# Out:
# Set A is : {1, 2, 4, 6, 7, 8}
# Set B is : {1, 2, 3, 4, 6, 9}
# Union of set A and B is(A|B): {1, 2, 3, 4, 6, 7, 8, 9}

# %%
#12
print("Intersection of A and B is (A&B):", A&B)
# Out:
# Intersection of A and B is (A&B): {1, 2, 4, 6}

# %%
#13
print("Unique element of set A by differance is:", A-B)
# Out:
# Unique element of set A by differance is: {8, 7}

# %%
#14
print("Symmetric diff between set A and B is :", A^B)
# Out:
# Symmetric diff between set A and B is : {3, 7, 8, 9}

# %%
print("Is A is subset of B?:", A.issubset(B)) #15
# Out:
# Is A is subset of B?: False

# %%
#16
print("Is B is superset of A?", B.issuperset(A))
# Out:
# Is B is superset of A? False

# %%
print("Is A and B have no common elements?:", A.isdisjoint(B)) #17
# Out:
# Is A and B have no common elements?: False

# %%
print("Is 6 present in set A?:", 6 in A) #18
# Out:
# Is 6 present in set A?: True

# %%
print("Is 20 not present in setB?:", 20 not in B) #19
# Out:
# Is 20 not present in setB?: True

# %%
print("Total num of elements in set A is:", len(A)) #20
# Out:
# Total num of elements in set A is: 6

# %%
print("Max in set A :", max(A)) #21
print("Min in set B :", min(B)) #21
# Out:
# Max in set A : 8
# Min in set B : 1

# %%
print("Sum of all elements in set A :", sum(A)) #22
# Out:
# Sum of all elements in set A : 28

# %%
sorted_listA = list(sorted(A)) #23
print("The sorted list from set A is:", sorted_listA)
# Out:
# The sorted list from set A is: [1, 2, 4, 6, 7, 8]

# %%
sorted_listB = list(sorted(B, reverse= True)) #24
print("The sorted list from set B in decending order is:", sorted_listB)
# Out:
# The sorted list from set B in decending order is: [9, 6, 4, 3, 2, 1]

# %%
status = {0,1,0,1,1}
print("Is any status are True?:", any(status)) #25
print("Is all status are True?:", all(status)) #26
# Out:
# Is any status are True?: True
# Is all status are True?: False

# %%
c = A.copy() #27
print("Copied set :", c)
c.add(3)
print("After add() on copied set, the copied set is:", c)
print("Original set is :", A) #Both are independent
# Out:
# Copied set : {1, 2, 4, 6, 7, 8}
# After add() on copied set, the copied set is: {1, 2, 3, 4, 6, 7, 8}
# Original set is : {1, 2, 4, 6, 7, 8}

# %%
del A # 28
# deleted entire set A

# %%
print("Set after del keyword:", A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 print("Set after del keyword:", A)
#
# NameError: name 'A' is not defined

# %%
lst = [ 12,65,13,87,12,65,45,24,15] #29
data = set(lst)
print("The set from list is:", data) #duplicates remove
# Out:
# The set from list is: {65, 12, 45, 13, 15, 87, 24}

# %%
classA = {"Apurva", "Tanisha", "Manthan", "Advait"} #30
classB = {"Tanisha", "Sarthak", "Soham", "Isha"}
print("Class A students are:", classA)
print("Class B students are:", classB)
# Out:
# Class A students are: {'Tanisha', 'Manthan', 'Advait', 'Apurva'}
# Class B students are: {'Sarthak', 'Soham', 'Isha', 'Tanisha'}

# %%
#Common students 30(a)
print("Common students from class A and B are :", classA&classB)
# Out:
# Common students from class A and B are : {'Tanisha'}

# %%
#students only in class A 30(b)
print("Students only in class A are:", classA-classB)
# Out:
# Students only in class A are: {'Manthan', 'Advait', 'Apurva'}

# %%
#all unique students 30(c)
print("All unique students from both class :", classA| classB)
# Out:
# All unique students from both class : {'Advait', 'Apurva', 'Isha', 'Sarthak', 'Soham', 'Manthan', 'Tanisha'}
