# %%
num_list = [21,53,75,32,65,23,78,23,14,56]
print(num_list)
# Out:
# [21, 53, 75, 32, 65, 23, 78, 23, 14, 56]

# %%
lst = [ 10, 12 , 3.14, 67 ]
print(type(lst[0]))
print(type(lst[1]))
print(type(lst[2]))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %%
print("First element of list :", lst[0])
print("last element of list :", lst[-1])
middle_value = lst[len(lst)//2]
print("Middle element of the list :", middle_value)
# Out:
# First element of list : 10
# last element of list : 67
# Middle element of the list : 3.14

# %%
print("Sliced list is :", num_list[:3]) #first 3
# Out:
# Sliced list is : [21, 53, 75]

# %%
print("Sliced list is :", num_list[-3:]) #last 3
# Out:
# Sliced list is : [23, 14, 56]

# %%
num_list[1] = 54
print("List after replace :", num_list)
# Out:
# List after replace : [21, 54, 75, 32, 65, 23, 78, 23, 14, 56]

# %%
num_list.append(99)
print("The updated list after append() :", num_list)
# Out:
# The updated list after append() : [21, 54, 75, 32, 65, 23, 78, 23, 14, 56, 99]

# %%
num_list.insert(2, 35)
print("The updated list after insert() :", num_list)
# Out:
# The updated list after insert() : [21, 54, 35, 75, 32, 65, 23, 78, 23, 14, 56, 99]

# %%
num_list.extend(lst)
print("The list after extend() :", num_list)
# Out:
# The list after extend() : [21, 54, 35, 75, 32, 65, 23, 78, 23, 14, 56, 99, 'abc', 12, 3.14]

# %%
num_list.remove("abc")
print("The list after remove() :", num_list)
# Out:
# The list after remove() : [21, 54, 35, 75, 32, 65, 23, 78, 23, 14, 56, 99, 12, 3.14]

# %%
removed_val = num_list.pop(3)
print("Removed element :", removed_val)
# Out:
# Removed element : 75

# %%
del num_list[0]
print(num_list)
# Out:
# [54, 35, 32, 65, 23, 78, 23, 14, 56, 99, 12, 3.14]

# %%
num_list.clear()
print("the list after clear() :", num_list)
# Out:
# the list after clear() : []

# %%
list1 = ["A", "B", "C", "T", "R"]
print("Is C present in list? :", "C" in list1 )
# Out:
# Is C present in list? : True

# %%
index = list1.index("B")
print(index)
# Out:
# 1

# %%
count = list1.count("T")
print(count)
# Out:
# 1

# %%
sorted_string = list1.sort(reverse=True)
print(sorted_string)
# Out:
# None

# %%
list2 = list1 + ["d", "e"]
print(list2)
# Out:
# ['T', 'R', 'C', 'B', 'A', 'd', 'e']

# %%
list3 = list1.copy()
print(list3)
# Out:
# ['T', 'R', 'C', 'B', 'A']

# %%
num = [ 4,2,8,5,0]
num.sort()
print(num)
# Out:
# [0, 2, 4, 5, 8]
